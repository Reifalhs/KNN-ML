# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# Load the dataset
df = pd.read_csv('FINAL_USO.csv')

# Data preprocessing
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
df.dropna(inplace=True)

# Use 'Close' column as the target variable
data = df['Close'].values.reshape(-1, 1)

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Split data into train and test sets
train_size = int(len(scaled_data) * 0.8)
test_size = len(scaled_data) - train_size
train_data, test_data = scaled_data[0:train_size,:], scaled_data[train_size:len(scaled_data),:]

# Function to create dataset for supervised learning
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Create train and test datasets
look_back = 1
trainX, trainY = create_dataset(train_data, look_back)
testX, testY = create_dataset(test_data, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# Build an ANN model
model = Sequential()
model.add(Dense(8, input_dim=look_back, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(trainX, trainY, epochs=100, batch_size=2, verbose=2, validation_data=(testX, testY), callbacks=[early_stopping])

# Make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# Inverse transform predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# Plot the results
plt.figure(figsize=(14, 7))
plt.plot(df.index[:len(train_data)], scaler.inverse_transform(train_data), label='Actual Train Prices')
plt.plot(df.index[len(train_data)+look_back+1:], scaler.inverse_transform(test_data), label='Actual Test Prices')
plt.plot(df.index[look_back:len(trainPredict)+look_back], trainPredict, label='Training Prediction')
plt.plot(df.index[len(train_data)+look_back*2+1:len(scaled_data)-1], testPredict, label='Testing Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Prediction')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 686/686 - 3s - loss: 0.0263 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 2/100
# 686/686 - 1s - loss: 0.0021 - val_loss: 1.6494e-04 - 998ms/epoch - 1ms/step
# Epoch 3/100
# 686/686 - 1s - loss: 3.6633e-04 - val_loss: 1.0512e-04 - 1s/epoch - 2ms/step
# Epoch 4/100
# 686/686 - 1s - loss: 3.5719e-04 - val_loss: 1.1533e-04 - 1s/epoch - 2ms/step
# Epoch 5/100
# 686/686 - 1s - loss: 3.5601e-04 - val_loss: 1.0377e-04 - 1s/epoch - 1ms/step
# Epoch 6/100
# 686/686 - 1s - loss: 3.5496e-04 - val_loss: 1.0844e-04 - 1s/epoch - 1ms/step
# Epoch 7/100
# 686/686 - 1s - loss: 3.5733e-04 - val_loss: 1.0383e-04 - 1s/epoch - 1ms/step
# Epoch 8/100
# 686/686 - 1s - loss: 3.5736e-04 - val_loss: 1.0355e-04 - 1s/epoch - 2ms/step
# Epoch 9/100
# 686/686 - 1s - loss: 3.5505e-04 - val_loss: 1.2296e-04 - 1s/epoch - 1ms/step
# Epoch 10/100
# 686/686 - 1s - loss: 3.6711e-04 - val_loss: 1.0265e-04 - 1s/epoch - 2ms/step
# Epoch 11/100
# ...
